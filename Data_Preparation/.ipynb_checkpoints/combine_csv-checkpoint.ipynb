# %%
import pandas as pd

# %%
df1=pd.read_csv('Bad_Quality_Data_Frames_output_cleaned_height_width.csv')
#df2=pd.read_csv('mpii_dataset_custom_height_width.csv')

# df = pd.concat([df1[:-int(len(df1)*0.08)], df2[:-int(len(df2)*0.08)]], axis=0)
# df_val = pd.concat([df1[-int(len(df1)*0.08):], df2[-int(len(df2)*0.08):]], axis=0)

df = df1[:-int(len(df1)*0.08)]
df_val = df1[-int(len(df1)*0.08):]

print(len(df))
df.to_csv('instances_train2017.csv',index=False)
df_val.to_csv('instances_val2017.csv',index=False)
# Out:
# 18969
