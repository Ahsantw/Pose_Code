# %%
import os
import glob

# %%
labels = glob.glob('new_dir/labels/train2017/*')
print(labels)
# Out:
# ['new_dir/labels/train2017/frame_100_18.txt', 'new_dir/labels/train2017/frame_100_19.txt', 'new_dir/labels/train2017/frame_100_2.txt', 'new_dir/labels/train2017/frame_100_20.txt', 'new_dir/labels/train2017/frame_100_21.txt', 'new_dir/labels/train2017/frame_100_22.txt', 'new_dir/labels/train2017/frame_100_23.txt', 'new_dir/labels/train2017/frame_100_24.txt', 'new_dir/labels/train2017/frame_100_25.txt', 'new_dir/labels/train2017/frame_100_26.txt', 'new_dir/labels/train2017/frame_100_27.txt', 'new_dir/labels/train2017/frame_100_28.txt', 'new_dir/labels/train2017/frame_100_29.txt', 'new_dir/labels/train2017/frame_100_3.txt', 'new_dir/labels/train2017/frame_100_30.txt', 'new_dir/labels/train2017/frame_100_31.txt', 'new_dir/labels/train2017/frame_100_32.txt', 'new_dir/labels/train2017/frame_100_38.txt', 'new_dir/labels/train2017/frame_100_39.txt', 'new_dir/labels/train2017/frame_100_40.txt', 'new_dir/labels/train2017/frame_100_41.txt', 'new_dir/labels/train2017/frame_100_42.txt', 'new_dir/
# ...

# %%
for lab in labels:
    name = os.path.basename(lab).split('.')[0]+'.jpg'
    os.system('mv new_dir/images/train2017/'+name+' new_dir/images_cleaned/train2017/')
